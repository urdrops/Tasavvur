# %%
import pandas as pd

df = pd.read_csv("example.csv")

print(df.head())
# Out:
#    №                     Регион 2000 год 2001 год 2002 год 2003 год  \
# 0  1                      всего        -     27.5     26.5     27.2
# 1  2                   б) город        -     22.5     21.8     22.6
# 2  3                 в) деревня        -     30.5     29.4     29.8
# 3  4  Республика Каракалпакстан        -        -        -        -
# 4  5                    Андижан        -        -        -        -
#
#     2004 год   2005 год   2006 год   2007 год  ...   2012 год   2013 год  \
# 0  26.100000  25.800000  24.900000  23.600000  ...  15.000000  14.100000
# 1  18.819148  18.282108  17.929701  17.569570  ...  11.600000  10.600000
# 2  30.256223  29.951353  28.839890  27.086729  ...  18.300000  17.300000
# 3  44.705882  44.032135  43.059401  41.649331  ...  32.472325  31.328671
# 4  23.519565  23.091133  22.215613  21.109764  ...  11.541889  10.790698
#
#    2014 год   2015 год  2016 год   2017 год  2018 год   2019 год   2020 год  \
# ...
